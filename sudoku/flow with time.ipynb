# %%
import os
import sys
import operator
import itertools
import heapq
from datetime import datetime
from argparse import ArgumentParser
from collections import defaultdict
import pycosat
import functools
from functools import reduce
import pandas as pd
import time
import collections
from collections import Counter


LEFT = 1
RIGHT = 2
TOP = 4
BOTTOM = 8

# %%
DELTAS = [(LEFT, 0, -1),
          (RIGHT, 0, 1),
          (TOP, -1, 0),
          (BOTTOM, 1, 0)]

LR = LEFT | RIGHT
TB = TOP | BOTTOM
TL = TOP | LEFT
TR = TOP | RIGHT
BL = BOTTOM | LEFT
BR = BOTTOM | RIGHT

DIR_TYPES = [LR, TB, TL, TR, BL, BR]

DIR_FLIP = {
    LEFT: RIGHT,
    RIGHT: LEFT,
    TOP: BOTTOM,
    BOTTOM: TOP
    }

ANSI_LOOKUP = dict(R=101, B=104, Y=103, G=42,
                   O=43, C=106, M=105, m=41,
                   P=45, A=100, W=107, g=102,
                   T=47, b=44, c=46, p=35)

ANSI_RESET = '\033[0m'

ANSI_CELL_FORMAT = '\033[30;{}m'

DIR_LOOKUP = {
    LR: '─',
    TB: '│',
    TL: '┘',
    TR: '└',
    BL: '┐',
    BR: '┌'
    }

RESULT_STRINGS = dict(s='successful',
                      f='failed',
                      u='unsolvable')

# %%
def parse_puzzle(options, file_or_str, filename='input'):

    '''Convert the given string or file object into a square array of
strings. Also return a dictionary which maps input characters to color
indices.

    '''

    if not isinstance(file_or_str, str):
        file_or_str = file_or_str.read()

    puzzle = file_or_str.splitlines()

    # assume size based on length of first line
    size = len(puzzle[0])

    # make sure enough lines
    if len(puzzle) < size:
        print('{}:{} unexpected EOF'.format(filename, len(puzzle)+1))
        return None, None

    # truncate extraneous lines
    puzzle = puzzle[:size]

    # count colors and build lookup
    colors = dict()
    color_count = []

    for i, row in enumerate(puzzle):
        if len(row) != size:
            print('{}:{} row size mismatch'.format(filename, i+1))
            return None, None
        for j, char in enumerate(row):
            if char.isalnum(): # flow endpoint
                if char in colors.keys():
                    color = colors[char]
                    if color_count[color]:
                        print('{}:{}:{} too many {} already'.format(filename, i+1, j, char))
                        return None, None
                    color_count[color] = 1
                else:
                    color = len(colors)
                    colors[char] = color
                    color_count.append(0)

    # check parity
    for char, color in colors.items():
        if not color_count[color]:
            print('color {} has start but no end!'.format(char))
            return None, None

  

    puzzle, colors = repair_colors(puzzle, colors)
    return puzzle, colors

# %%
def make_dir_vars(puzzle, start_var):

    '''Creates the direction-type SAT variables for each cell.'''

    size = len(puzzle)
    dir_vars = dict()
    num_dir_vars = 0

    for i, j, char in explode(puzzle):

        if char.isalnum(): # flow endpoint, no dir needed
            continue

        # collect bits for neighbors (TOP BOTTOM LEFT RIGHT)
        neighbor_bits = (dir_bit for (dir_bit, ni, nj)
                         in valid_neighbors(size, i, j))

        # OR them all together
        cell_flags = reduce(operator.or_, neighbor_bits, 0)

        # create a lookup for dir type vars in this cell
        dir_vars[i, j] = dict()

        for code in DIR_TYPES:
            # only add var if cell has correct flags (i.e. if cell has
            # TOP, BOTTOM, RIGHT, don't add LR).
            if cell_flags & code == code:
                num_dir_vars += 1
                dir_vars[i, j][code] = start_var + num_dir_vars

    return dir_vars, num_dir_vars

######################################################################

def make_dir_clauses2(puzzle, colors, color_var, dir_vars):

    '''Generate clauses involving the color and direction-type SAT
variables. Each free cell must be exactly one direction, and
directions imply color matching with neighbors.

    '''

    dir_clauses = []
    num_colors = len(colors)
    size = len(puzzle)

    # for each cell
    for i, j, char in explode(puzzle):

        if char.isalnum(): # flow endpoint, no dir needed
            continue

        cell_dir_dict = dir_vars[(i, j)]
        cell_dir_vars = cell_dir_dict.values()
        
        
        ##################################adding time value##########################
        # at least one direction is set in this cell
        dir_clauses.append(("time_direction: ", time.time()))
        dir_clauses.append(cell_dir_vars)
        
        ##################################adding time value##########################
        # no two directions are set in this cell
        dir_clauses.append(("time_direction_no_two: ", time.time()))
        dir_clauses.extend(no_two(cell_dir_vars))

        # for each color
        for color in range(num_colors):

            # get color var for this cell
            color_1 = color_var(i, j, color)

            # for each neighbor
            for dir_bit, n_i, n_j in all_neighbors(i, j):

                # get color var for other cell
                color_2 = color_var(n_i, n_j, color)

                # for each direction variable in this scell
                for dir_type, dir_var in cell_dir_dict.items():

                    # if neighbor is hit by this direction type
                    if dir_type & dir_bit:
                         ##################################adding time value##########################
                        # this direction type implies the colors are equal
                        dir_clauses.append(("time_direction_imply_color: ", time.time()))
                        dir_clauses.append([-dir_var, -color_1, color_2])
                        dir_clauses.append(("time_direction_imply_color: ", time.time()))
                        dir_clauses.append([-dir_var, color_1, -color_2])
                    elif valid_pos(size, n_i, n_j):
                         ##################################adding time value##########################
                        # neighbor is not along this direction type,
                        # so this direction type implies the colors are not equal
                        dir_clauses.append(("time_direction_reduce_neigbor: ", time.time()))
                        dir_clauses.append([-dir_var, -color_1, -color_2])

    return dir_clauses

# %%
def make_dir_clauses(puzzle, colors, color_var, dir_vars):

    '''Generate clauses involving the color and direction-type SAT
variables. Each free cell must be exactly one direction, and
directions imply color matching with neighbors.

    '''

    dir_clauses = []
    num_colors = len(colors)
    size = len(puzzle)

    # for each cell
    for i, j, char in explode(puzzle):

        if char.isalnum(): # flow endpoint, no dir needed
            continue

        cell_dir_dict = dir_vars[(i, j)]
        cell_dir_vars = cell_dir_dict.values()
        
        
        ##################################adding time value##########################
        # at least one direction is set in this cell
        #dir_clauses.append(("time_direction: ", time.time()))
        dir_clauses.append(cell_dir_vars)
        
        ##################################adding time value##########################
        # no two directions are set in this cell
       # dir_clauses.append(("time_direction_no_two: ", time.time()))
        dir_clauses.extend(no_two(cell_dir_vars))

        # for each color
        for color in range(num_colors):

            # get color var for this cell
            color_1 = color_var(i, j, color)

            # for each neighbor
            for dir_bit, n_i, n_j in all_neighbors(i, j):

                # get color var for other cell
                color_2 = color_var(n_i, n_j, color)

                # for each direction variable in this scell
                for dir_type, dir_var in cell_dir_dict.items():

                    # if neighbor is hit by this direction type
                    if dir_type & dir_bit:
                         ##################################adding time value##########################
                        # this direction type implies the colors are equal
                        #dir_clauses.append(("time_direction_imply_color: ", time.time()))
                        dir_clauses.append([-dir_var, -color_1, color_2])
                        #dir_clauses.append(("time_direction_imply_color: ", time.time()))
                        dir_clauses.append([-dir_var, color_1, -color_2])
                    elif valid_pos(size, n_i, n_j):
                         ##################################adding time value##########################
                        # neighbor is not along this direction type,
                        # so this direction type implies the colors are not equal
                        #dir_clauses.append(("time_direction_reduce_neigbor: ", time.time()))
                        dir_clauses.append([-dir_var, -color_1, -color_2])

    return dir_clauses

# %%
def make_color_clauses2(puzzle, colors, color_var):

    '''Generate CNF clauses entailing the N*M color SAT variables, where N
is the number of cells and M is the number of colors. Each cell
encodes a single color in a one-hot fashion.

    '''

    clauses = []
    num_colors = len(colors)
    size = len(puzzle)

    # for each cell
    for i, j, char in explode(puzzle):

        if char.isalnum(): # flow endpoint

            endpoint_color = colors[char] #valid number

            ##########################_adding_time_variable_###################### 
            # color in this cell is this one
            clauses.append(("time_endpoint_color: ", time.time()))
            clauses.append([color_var(i, j, endpoint_color)])

            # color in this cell is not the other ones
            for other_color in range(num_colors):
                if other_color != endpoint_color:
                    clauses.append(("time_endpoint_color_negetions: ", time.time()))
                    clauses.append([-color_var(i, j, other_color)])

            # gather neighbors' variables for this color
            neighbor_vars = [color_var(ni, nj, endpoint_color) for
                             _, ni, nj in valid_neighbors(size, i, j)]

            ##########################_adding_time_variable_######################
            # one neighbor has this color
            clauses.append(("time_endpoint_color_neighbor: ", time.time()))
            clauses.append(neighbor_vars)

            ##########################_adding_time_variable_######################
            # no two neighbors have this color
            clauses.append(("time_endpoint_color_neighbor_no_two: ", time.time()))
            clauses.extend(no_two(neighbor_vars))

        else:
            ##########################_adding_time_variable_######################
            # one of the colors in this cell is set
            clauses.append(("time__color_cell: ", time.time()))
            clauses.append([color_var(i, j, color)
                            for color in range(num_colors)])

            # no two of the colors in this cell are set
            cell_color_vars = (color_var(i, j, color) for
                               color in range(num_colors))
            clauses.append(("time__color_cell_no_two: ", time.time()))
            clauses.extend(no_two(cell_color_vars))

    return clauses

######################################################################

# %%
def make_color_clauses(puzzle, colors, color_var):

    '''Generate CNF clauses entailing the N*M color SAT variables, where N
is the number of cells and M is the number of colors. Each cell
encodes a single color in a one-hot fashion.

    '''

    clauses = []
    num_colors = len(colors)
    size = len(puzzle)

    # for each cell
    for i, j, char in explode(puzzle):

        if char.isalnum(): # flow endpoint

            endpoint_color = colors[char] #valid number

            ##########################_adding_time_variable_###################### 
            # color in this cell is this one
            #clauses.append(("time_endpoint_color: ", time.time()))
            clauses.append([color_var(i, j, endpoint_color)])

            # color in this cell is not the other ones
            for other_color in range(num_colors):
                if other_color != endpoint_color:
                    #clauses.append(("time_endpoint_color_negetions: ", time.time()))
                    clauses.append([-color_var(i, j, other_color)])

            # gather neighbors' variables for this color
            neighbor_vars = [color_var(ni, nj, endpoint_color) for
                             _, ni, nj in valid_neighbors(size, i, j)]

            ##########################_adding_time_variable_######################
            # one neighbor has this color
           # clauses.append(("time_endpoint_color_neighbor: ", time.time()))
            clauses.append(neighbor_vars)

            ##########################_adding_time_variable_######################
            # no two neighbors have this color
            #clauses.append(("time_endpoint_color_neighbor_no_two: ", time.time()))
            clauses.extend(no_two(neighbor_vars))

        else:
            ##########################_adding_time_variable_######################
            # one of the colors in this cell is set
            #clauses.append(("time__color_cell: ", time.time()))
            clauses.append([color_var(i, j, color)
                            for color in range(num_colors)])

            # no two of the colors in this cell are set
            cell_color_vars = (color_var(i, j, color) for
                               color in range(num_colors))
            #clauses.append(("time__color_cell_no_two: ", time.time()))
            clauses.extend(no_two(cell_color_vars))

    return clauses

######################################################################

# %%
def explode(puzzle):
    '''Iterator helper function to allow looping over 2D arrays without
nested 'for' loops.

    '''

    for i, row in enumerate(puzzle):
        for j, char in enumerate(row):
            yield i, j, char

# %%
def no_two(satvars):
    '''Given a collection of SAT variables, generates clauses specifying
that no two of them can be true at the same time.

    '''

    return ((-a, -b) for (a, b) in all_pairs(satvars))

# %%
def all_pairs(collection):
    '''Return all combinations of two items from a collection, useful for
making a large number of SAT variables mutually exclusive.

    '''

    return itertools.combinations(collection, 2)

# %%
def valid_pos(size, i, j):
    '''Check whether a position on a square grid is valid.'''
    return i >= 0 and i < size and j >= 0 and j < size

######################################################################

def all_neighbors(i, j):
    '''Return all neighbors of a grid square at row i, column j.'''
    return ((dir_bit, i+delta_i, j+delta_j)
            for (dir_bit, delta_i, delta_j) in DELTAS)

######################################################################

def valid_neighbors(size, i, j):
    '''Return all actual on-grid neighbors of a grid square at row i,
column j.'''

    return ((dir_bit, ni, nj) for (dir_bit, ni, nj)
            in all_neighbors(i, j)
            if valid_pos(size, ni, nj))

# %%
def repair_colors(puzzle, colors):

    '''If the puzzle file used "color labels" (A,B,C...), instead
    of color mnemonics (R,G,B...), convert the labels to mnemonics.
    Note: If a puzzle is in mnemonic format, it will contain the
    letter 'R' since Red is always the first color. Absence of an 'R'
    is the test for a color-labeled puzzle.
    '''
    if 'R' in colors.keys():
        return puzzle, colors

    color_lookup = 'RBYGOCMmPAWgTbcp'
    new_puzzle = []

    try:

        for row in puzzle:

            new_row = []

            for char in row:
                if char.isalnum():
                    char = color_lookup[ord(char)-ord('A')]
                new_row.append(char)

            new_puzzle.append(''.join(new_row))

        new_colors = dict((color_lookup[ord(char)-ord('A')], index)
                          for (char, index) in colors.items())

    except IndexError:
        return puzzle, colors

    return new_puzzle, new_colors

######################################################################

# %%
def decode_solution(puzzle, colors, color_var, dir_vars, sol):

    '''Takes the solution set from SAT and decodes it by undoing the
one-hot encoding in each cell for color and direction-type. Returns a
2D array of (color, direction-type) pairs.

    '''

    sol = set(sol)
    num_colors = len(colors)

    decoded = []

    for i, row in enumerate(puzzle):

        decoded_row = []

        for j, char in enumerate(row):

            # find which color variable for this cell is in the
            # solution set
            cell_color = -1

            for color in range(num_colors):
                if color_var(i, j, color) in sol:
                    assert cell_color == -1
                    cell_color = color

            assert cell_color != -1

            cell_dir_type = -1

            if not char.isalnum(): # not a flow endpoint

                # find which dir type variable for this cell is in the
                # solution set
                for dir_type, dir_var in dir_vars[i, j].items():
                    if dir_var in sol:
                        assert cell_dir_type == -1
                        cell_dir_type = dir_type

                assert cell_dir_type != -1

            decoded_row.append((cell_color, cell_dir_type))

        decoded.append(decoded_row)

    return decoded

# %%
def reduce_to_sat2(options, puzzle, colors):

    '''Reduces the given puzzle to a SAT problem specified in CNF. Returns
a list of clauses where each clause is a list of single SAT variables,
possibly negated.

    '''

    size = len(puzzle)
    num_colors = len(colors)

    num_cells = size**2
    num_color_vars = num_colors * num_cells

    def color_var(i, j, color):
        '''Return the index of the SAT variable for the given color in row i,
 column j.

        '''
        return (i*size + j)*num_colors + color + 1

    start = datetime.now()

    color_clauses = make_color_clauses2(puzzle,
                                       colors,
                                       color_var)

    dir_vars, num_dir_vars = make_dir_vars(puzzle, num_color_vars)

    dir_clauses = make_dir_clauses2(puzzle, colors,
                                   color_var, dir_vars)

    num_vars = num_color_vars + num_dir_vars
    clauses = color_clauses + dir_clauses

    reduce_time = (datetime.now() - start).total_seconds()

    

    return color_var, dir_vars, num_vars, clauses, reduce_time

######################################################################

# %%
def reduce_to_sat(options, puzzle, colors):

    '''Reduces the given puzzle to a SAT problem specified in CNF. Returns
a list of clauses where each clause is a list of single SAT variables,
possibly negated.

    '''

    size = len(puzzle)
    num_colors = len(colors)

    num_cells = size**2
    num_color_vars = num_colors * num_cells

    def color_var(i, j, color):
        '''Return the index of the SAT variable for the given color in row i,
 column j.

        '''
        return (i*size + j)*num_colors + color + 1

    start = datetime.now()

    color_clauses = make_color_clauses(puzzle,
                                       colors,
                                       color_var)

    dir_vars, num_dir_vars = make_dir_vars(puzzle, num_color_vars)

    dir_clauses = make_dir_clauses(puzzle, colors,
                                   color_var, dir_vars)

    num_vars = num_color_vars + num_dir_vars
    clauses = color_clauses + dir_clauses

    reduce_time = (datetime.now() - start).total_seconds()

    

    return color_var, dir_vars, num_vars, clauses, reduce_time

######################################################################

# %%
def solve_sat(options, puzzle, colors, color_var, dir_vars, clauses):

    '''Solve the SAT now that it has been reduced to a list of clauses in
CNF.  This is an iterative process: first we try to solve a SAT, then
we detect cycles. If cycles are found, they are prevented from
recurring, and the next iteration begins. Returns the SAT solution
set, the decoded puzzle solution, and the number of cycle repairs
needed.

    '''

    start = datetime.now()

    decoded = None
    all_decoded = []
    repairs = 0

    while True:

        sol = pycosat.solve(clauses) # pylint: disable=E1101

        if not isinstance(sol, list):
            decoded = None
            all_decoded.append(decoded)
            break

        decoded = decode_solution(puzzle, colors, color_var, dir_vars, sol)
        all_decoded.append(decoded)

#         extra_clauses = detect_cycles(decoded, dir_vars)

#         if not extra_clauses:
#             break

#         clauses += extra_clauses
#         repairs += 1

#     solve_time = (datetime.now() - start).total_seconds()

#     if not options.quiet:
#         if options.display_cycles:
#             for cycle_decoded in all_decoded[:-1]:
#                 print('intermediate solution with cycles:')
#                 show_solution(options, colors, cycle_decoded)


#         if decoded is None:
#             print('solver returned {} after {:,} cycle repairs and {:.3f} seconds'.format(str(sol), repairs, solve_time))
#         else:
#             print('obtained solution after {:,} cycle repairs and {:.3f} seconds:'.format(repairs, solve_time))
#             show_solution(options, colors, decoded)

    return sol, decoded, repairs, solve_time

# %%
def print_summary(filename, stats):

    '''Print out stats for all solutions.'''
    
    max_width = max(len(f) for f in filename)
    

    solution_types = stats.keys()

    all_stats = defaultdict(float)
   
    for result_char in solution_types:
        for k in stats[result_char]:
            all_stats[k] += stats[result_char][k]
            
    print(stats)

#     if all_stats['count'] > 1:
#         print('t')

    print('\n'+('*'*70)+'\n')

    for result_char in solution_types:

        print('{:d} {:s} searches took:\n'\
            '  {:,.3f} sec. to reduce '\
            '(with {:,d} variables and {:,d} clauses)\n'\
            '  {:,.3f} sec. to solve (with {:d} repairs)\n'\
            '  {:,.3f} sec. total\n'.format(
                stats[result_char]['count'], result_char,
                stats[result_char]['reduce_time'],
                stats[result_char]['num_vars'],
                stats[result_char]['num_clauses'],
                stats[result_char]['solve_time'],
                stats[result_char]['repairs'],
                stats[result_char]['total_time']))

        

        print('overall, {:d} searches took:\n'\
            '  {:,.3f} sec. to reduce '\
            '(with {:,d} variables and {:,d} clauses)\n'\
            '  {:,.3f} sec. to solve (with {:d} repairs)\n'\
            '  {:,.3f} sec. total\n'.format(
                int(all_stats['count']),
                all_stats['reduce_time'],
                int(all_stats['num_vars']),
                int(all_stats['num_clauses']),
                all_stats['solve_time'],
                int(all_stats['repairs']),
                all_stats['total_time']))

        for result_char in solution_types:

            print('{:s}{:3d} total {:s} {:9,d} {:9,d} {:12,.3f} '\
                '{:3d} {:12,.3f} {:12,.3f}'.format(
                    ' '*(max_width-9), stats[result_char]['count'],
                    result_char,
                    stats[result_char]['num_vars'],
                    stats[result_char]['num_clauses'],
                    stats[result_char]['reduce_time'],
                    stats[result_char]['repairs'],
                    stats[result_char]['solve_time'],
                    stats[result_char]['total_time']))

#         if len(solution_types) > 1:

        print('{:s}{:3d} overall {:9,d} {:9,d} {:12,.3f} '\
            '{:3d} {:12,.3f} {:12,.3f}'.format(
                ' '*(max_width-9), int(all_stats['count']),
                int(all_stats['num_vars']), int(all_stats['num_clauses']),
                all_stats['reduce_time'], int(all_stats['repairs']),
                all_stats['solve_time'], all_stats['total_time']))

######################################################################

# %%
    def check_circle(clauses,all_times):        
        while(True):
            for i, item in enumerate(clauses):
                if (type(item)==tuple and (item[1])>(1589745930)):
                    for j, val in enumerate(clauses):
                         if (type(val)==tuple and val[1]>(1589745930)):
                            all_times[(item[0],item[1])]=clauses[i+1:j-1]

# %%
def is_circle(directions_and_color):
    for v in directions_and_color.values():
        for v2 in directions_and_color.values():
            if v!= v2:
                list_values_v=[t for t in v if  type(t)==list ]
                list_values_v2=[t2 for t2 in v2 if  type(t2)==list ]
                for item in list_values_v:
                    for item2 in list_values_v2:
                        numN=(abs(item[0]))
                        num=[int(i) for i in str(numN)]
                        num2N=(abs(item2[0]))
                        num2=[int(i) for i in str(num2N)]
                        if (((num[0]==1+num2[0]) or(num[1]==1+num2[1])or (num[2]==1+num2[2]) )and item[1]==item2[1] and item[2]==item2[2]):
                            print('circle')
                            return True
    return False

# %%
def pyflow_solver_main():
    
    filename=r"C:\Users\vicli\Desktop\תמר לימודים\תואר שני\thesis\documation\sudoku\sudoku-sat-solver\flow game using sat\flow_solver_with_sat\puzzles\extreme_8x8_01.txt"
    
    options=''
    
    stats = {}
    with open(filename, 'r') as infile:
                puzzle, colors = parse_puzzle(options, infile, filename)

    start = time.time()
    color_var, dir_vars, num_vars, clauses2, reduce_time = reduce_to_sat2(options, puzzle, colors)
    color_var, dir_vars, num_vars, clauses, reduce_time = reduce_to_sat(options, puzzle, colors)
    all_times={}
    
#     for clause in clauses2:
# #         print('t')
#          if (type(clause)==tuple):
#             print('\nclause:\n', clause)
# #             for clause2 in ((clauses2)):
# #                 if type(clause2)==tuple and 'time' in clause2:
# #                     print(clause2)
# #                    # all_time[clause[1]]= 
    
#     def check_circle(clauses2):  
#         print('t')
#         while(True):
#             for i, item in enumerate(clauses):
# #                 print(item)
#                 if (type(item)==tuple and (item[1])>([all_times.keys()][0])):
#                     for j, val in enumerate(clauses):
#                          if (type(val)==tuple and val[1]>([all_times.keys()][0])):
#                             all_times[(item[0],item[1])]=clauses[i+1:j-1]

#             directions_and_color={}
#             #taking only clauses of "time_direction_direction_imply_color":
#             for key in all_times.keys():
#                 print(key[0])
#                 if key[0]=='time_direction_direction_imply_color: ':
#                     directions_and_color[key[1]]=all_times[key]

#                 circle=is_circle(directions_and_color)
#                 if not circle:
#                     break
#                 return clauses
        
#     clauses=check_circle(clauses2)
    print(clauses)

    
#         #########befor here. to think how i can check cycles here
    sol, _, repairs, solve_time = solve_sat(options, puzzle, colors,color_var, dir_vars, clauses)


    total_time = reduce_time + solve_time

    if isinstance(sol, list):
        result_char = 's'
    elif str(sol) == 'UNSAT':
        result_char = 'u'
    else:
        result_char = 'f'

    cur_stats = dict(repairs=repairs,
                     reduce_time=reduce_time,
                     solve_time=solve_time,
                     total_time=total_time,
                     num_vars=num_vars,
                     num_clauses=len(clauses),
                     count=1)

    if not result_char in stats.keys():
        stats[result_char] = cur_stats
    else:
        for key in cur_stats.keys():
            stats[result_char][key] += cur_stats[key]

    if not options.quiet:
        print('finished in total of {:.3f} seconds'.format(total_time))
    else:

        print('{:>{}s} {} {:9,d} {:9,d} {:12,.3f} '\
            '{:3d} {:12,.3f} {:12,.3f}'.format(
                filename, max_width, result_char,
                num_vars, len(clauses), reduce_time,
                repairs, solve_time, total_time))

    print(clauses, stats)

    print_summary(filename, stats)

# %%
if __name__ == '__main__':
    
    pyflow_solver_main()
# Out:
# [[1, 2, 3, 4, 5], (-1, -2), (-1, -3), (-1, -4), (-1, -5), (-2, -3), (-2, -4), (-2, -5), (-3, -4), (-3, -5), (-4, -5), [6, 7, 8, 9, 10], (-6, -7), (-6, -8), (-6, -9), (-6, -10), (-7, -8), (-7, -9), (-7, -10), (-8, -9), (-8, -10), (-9, -10), [11, 12, 13, 14, 15], (-11, -12), (-11, -13), (-11, -14), (-11, -15), (-12, -13), (-12, -14), (-12, -15), (-13, -14), (-13, -15), (-14, -15), [16, 17, 18, 19, 20], (-16, -17), (-16, -18), (-16, -19), (-16, -20), (-17, -18), (-17, -19), (-17, -20), (-18, -19), (-18, -20), (-19, -20), [21, 22, 23, 24, 25], (-21, -22), (-21, -23), (-21, -24), (-21, -25), (-22, -23), (-22, -24), (-22, -25), (-23, -24), (-23, -25), (-24, -25), [26, 27, 28, 29, 30], (-26, -27), (-26, -28), (-26, -29), (-26, -30), (-27, -28), (-27, -29), (-27, -30), (-28, -29), (-28, -30), (-29, -30), [31, 32, 33, 34, 35], (-31, -32), (-31, -33), (-31, -34), (-31, -35), (-32, -33), (-32, -34), (-32, -35), (-33, -34), (-33, -35), (-34, -35), [36, 37, 38, 39, 40], (-36, -37), (-36, -38), (-36, -39), (-36, -40), (-37, -38), (-37, -39), (-37, -40), (-38, -39), (-38, -40), (-39, -40), [41, 42, 43, 44, 45], (-41, -42), (-41, -43), (-41, -44), (-41, -45), (-42, -43), (-42, -44), (-42, -45), (-43, -44), (-43, -45), (-44, -45), [46], [-47], [-48], [-49], [-50], [41, 51, 6, 86], (-41, -51), (-41, -6), (-41, -86), (-51, -6), (-51, -86), (-6, -86), [51, 52, 53, 54, 55], (-51, -52), (-51, -53), (-51, -54), (-51, -55), (-52, -53), (-52, -54), (-52, -55), (-53, -54), (-53, -55), (-54, -55), [56, 57, 58, 59, 60], (-56, -57), (-56, -58), (-56, -59), (-56, -60), (-57, -58), (-57, -59), (-57, -60), (-58, -59), (-58, -60), (-59, -60), [61, 62, 63, 64, 65], (-61, -62), (-61, -63), (-61, -64), (-61, -65), (-62, -63), (-62, -64), (-62, -65), (-63, -64), (-63, -65), (-64, -65), [66, 67, 68, 69, 70], (-66, -67), (-66, -68), (-66, -69), (-66, -70), (-67, -68), (-67, -69), (-67, -70), (-68, -69), (-68, -70), (-69, -70), [71, 72, 73, 74, 75], (-71, -72), (-71, -73), (-71, -74), (-71, -75), (-72, -73), (-72, -74), (-72, -75), (-73, -74), (-73, -75), (-74, -75), [76, 77, 78, 79, 80], (-76, -77), (-76, -78), (-76, -79), (-76, -80), (-77, -78), (-77, -79), (-77, -80), (-78, -79), (-78, -80), (-79, -80), [81, 82, 83, 84, 85], (-81, -82), (-81, -83), (-81, -84), (-81, -85), (-82, -83), (-82, -84), (-82, -85), (-83, -84), (-83, -85), (-84, -85), [86, 87, 88, 89, 90], (-86, -87), (-86, -88), (-86, -89), (-86, -90), (-87, -88), (-87, -89), (-87, -90), (-88, -89), (-88, -90), (-89, -90), [91, 92, 93, 94, 95], (-91, -92), (-91, -93), (-91, -94), (-91, -95), (-92, -93), (-92, -94), (-92, -95), (-93, -94), (-93, -95), (-94, -95), [96, 97, 98, 99, 100], (-96, -97), (-96, -98), (-96, -99), (-96, -100), (-97, -98), (-97, -99), (-97, -100), (-98, -99), (-98, -100), (-99, -100), [101, 102, 103, 104, 105], (-101, -102), (-101, -103), (-101, -104), (-101, -105), (-102, -103), (-102, -104), (-102, -105), (-103, -104), (-103, -105), (-104, -105), [106, 107, 108, 109, 110], (-106, -107), (-106, -108), (-106, -109), (-106, -110), (-107, -108), (-107, -109), (-107, -110), (-108, -109), (-108, -110), (-109, -110), [111, 112, 113, 114, 115], (-111, -112), (-111, -113), (-111, -114), (-111, -115), (-112, -113), (-112, -114), (-112, -115), (-113, -114), (-113, -115), (-114, -115), [116, 117, 118, 119, 120], (-116, -117), (-116, -118), (-116, -119), (-116, -120), (-117, -118), (-117, -119), (-117, -120), (-118, -119), (-118, -120), (-119, -120), [121, 122, 123, 124, 125], (-121, -122), (-121, -123), (-121, -124), (-121, -125), (-122, -123), (-122, -124), (-122, -125), (-123, -124), (-123, -125), (-124, -125), [126, 127, 128, 129, 130], (-126, -127), (-126, -128), (-126, -129), (-126, -130), (-127, -128), (-127, -129), (-127, -130), (-128, -129), (-128, -130), (-129, -130), [131, 132, 133, 134, 135], (-131, -132), (-131, -133), (-131, -134), (-131, -135), (-132, -133), (-132, -134), (-132, -135), (-133, -134), (-133, -135), (-134, -135), [136, 137, 138, 139, 140], (-136, -137), (-136, -138 ...

# %%
#(i*size+j)*numcolors +color +1

# %%
all_times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-cee22ab88928> in <module>
# ----> 1 all_times
#
# NameError: name 'all_times' is not defined

# %%
# create new clouses that combined no - | - | in the same color one after anothe

# %%
directions_and_color={}
#taking only clauses of "time_direction_direction_imply_color":
for key in all_times.keys():
    print(key[0])
    if key[0]=='time_direction_direction_imply_color: ':
        directions_and_color[key[1]]=all_times[key]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-e99190f2cd46> in <module>
#       2 directions_and_color={}
#       3 #taking only clauses of "time_direction_direction_imply_color":
# ----> 4 for key in all_times.keys():
#       5     print(key[0])
#       6     if key[0]=='time_direction_direction_imply_color: ':
#
# NameError: name 'all_times' is not defined

# %%
directions_and_color
# Out:
# {1589834045.6364648: [[-321, 1, -41],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -2, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 2, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -2, 42],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 2, -42],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -3, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 3, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -3, 43],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 3, -43],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -4, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 4, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -4, 44],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 4, -44],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -5, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 5, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -5, 45],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 5, -45],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([322, 323, 324]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-322, -323),
#   (-322, -324),
#   (-323, -324),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -6, 1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 6, -1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -6, 1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 6, -1],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -6, -1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -6, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 6, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -6, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -6, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 6, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -6, 46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -6, 46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -7, 2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 7, -2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -7, 2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 7, -2],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -7, -2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -7, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 7, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -7, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -7, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 7, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -7, 47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -7, 47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -8, 3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 8, -3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -8, 3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 8, -3],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -8, -3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -8, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 8, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -8, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -8, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 8, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -8, 48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -8, 48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -9, 4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 9, -4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -9, 4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 9, -4],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -9, -4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -9, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 9, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -9, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -9, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 9, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -9, 49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -9, 49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -10, 5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 10, -5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -10, 5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 10, -5],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -10, -5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -10, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 10, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -10, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -10, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 10, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -10, -50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -10, 50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 10, -50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -10, 50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 10, -50],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([325, 326, 327]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-325, -326),
#   (-325, -327),
#   (-326, -327),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -11, 6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 11, -6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -11, 6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 11, -6],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -11, -6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -11, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 11, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -11, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -11, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 11, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -11, 51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -11, 51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -12, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 12, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -12, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 12, -7],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -12, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -12, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 12, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -12, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -12, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 12, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -12, 52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -12, 52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -13, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 13, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -13, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 13, -8],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -13, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -13, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 13, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -13, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -13, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 13, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -13, 53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -13, 53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -14, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 14, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -14, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 14, -9],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -14, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -14, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 14, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -14, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -14, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 14, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -14, 54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -14, 54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -15, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 15, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -15, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 15, -10],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -15, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -15, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 15, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -15, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -15, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 15, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -15, -55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -15, 55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 15, -55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -15, 55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 15, -55],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([328, 329, 330]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-328, -329),
#   (-328, -330),
#   (-329, -330),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -16, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 16, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -16, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 16, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -16, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -16, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 16, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -16, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -16, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 16, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -16, 56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -16, 56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -17, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 17, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -17, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 17, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -17, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -17, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 17, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -17, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -17, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 17, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -17, 57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -17, 57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -18, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 18, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -18, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 18, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -18, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -18, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 18, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -18, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -18, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 18, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -18, 58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -18, 58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -19, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 19, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -19, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 19, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -19, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -19, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 19, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -19, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -19, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 19, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -19, 59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -19, 59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -20, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 20, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -20, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 20, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -20, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -20, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 20, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -20, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -20, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 20, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -20, -60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -20, 60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 20, -60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -20, 60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 20, -60],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([331, 332, 333]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-331, -332),
#   (-331, -333),
#   (-332, -333),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -21, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 21, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -21, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 21, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-333, -21, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -21, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 21, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-332, -21, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -21, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 21, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-331, -21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -21, 61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -21, 61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -22, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 22, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -22, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 22, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-333, -22, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -22, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-332, -22, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -22, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384628),
#   [-331, -22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-331, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -23, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -24, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -25, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -65],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([334, 335, 336]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-334, -335),
#   (-334, -336),
#   (-335, -336),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -26, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -27, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -28, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 28, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -28, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 28, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -28, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -28, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 28, -33],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -28, -33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -28, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 28, -33],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -28, 68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -28, 68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -29, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 29, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -29, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 29, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -29, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -29, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 29, -34],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -29, -34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -29, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 29, -34],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -29, 69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -29, 69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -30, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 30, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -30, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 30, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -30, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -30, 35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 30, -35],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -30, -35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -30, 35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 30, -35],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -30, -70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -30, 70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 30, -70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -30, 70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 30, -70],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([337, 338, 339]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-337, -338),
#   (-337, -339),
#   (-338, -339),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -31, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 31, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -31, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 31, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -31, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -31, 36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 31, -36],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -31, -36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -31, 36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 31, -36],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -31, 71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -31, 71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -32, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 32, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -32, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 32, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -32, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -32, 37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 32, -37],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -32, -37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -32, 37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 32, -37],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -32, 72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -32, 72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -33, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 33, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -33, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 33, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -33, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -33, 38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 33, -38],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -33, -38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -33, 38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 33, -38],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -33, 73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -33, 73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -34, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 34, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -34, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 34, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -34, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -34, 39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 34, -39],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -34, -39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -34, 39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 34, -39],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -34, 74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -34, 74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -35, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 35, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -35, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 35, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -35, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -35, 40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 35, -40],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -35, -40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -35, 40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 35, -40],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -35, -75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -35, 75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 35, -75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -35, 75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 35, -75],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([340]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -36, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 36, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -36, 76],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 36, -76],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -37, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 37, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -37, 77],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 37, -77],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -38, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 38, -33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -38, 78],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 38, -78],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -39, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 39, -34],
#   ...],
#  1589834045.6374643: [[-333, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384628),
#   [-331, -22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-331, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -23, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -24, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -25, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -65],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([334, 335, 336]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-334, -335),
#   (-334, -336),
#   (-335, -336),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -26, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -27, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
# ...
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -271, -266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -271, 266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 271, -266],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -271, -266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -271, -276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -271, -276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 271, -311],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -271, -311],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -272, -277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -272, -277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 272, -312],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -272, -312],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -273, -278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -273, -278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 273, -313],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -273, -313],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -274, -279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -274, -279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 274, -314],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -274, -314],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -275, -280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -275, -280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 275, -315],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -275, -315],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 275, -315],
#   ('time_direction: ', 1589834045.6609497),
#   dict_values([554, 555, 556]),
#   ('time_direction_no_two: ', 1589834045.6609497),
#   (-554, -555),
#   (-554, -556),
#   (-555, -556),
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, -286, 281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, 286, -281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-555, -286, 281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-555, 286, -281],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-556, -286, -281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, -286, 291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, 286, -291],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-555, -286, -291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-556, -286, 291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-556, 286, -291],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   ...],
#  1589834045.6609497: []}

# %%
directions_and_color.keys()
# Out:
# dict_keys([1589834045.6364648, 1589834045.6374643, 1589834045.6384628, 1589834045.6384883, 1589834045.63949, 1589834045.6403875, 1589834045.6413882, 1589834045.6420665, 1589834045.6430666, 1589834045.6471267, 1589834045.6592376, 1589834045.6609497])

# %%
# #for k,v in directions_and_color.items():
# good = [t for t in directions_and_color.values() if not 'time' in (t) ]

# %%
(list(directions_and_color.values()))
# Out:
# [[[-321, 1, -41],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -2, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 2, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -2, 42],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 2, -42],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -3, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 3, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -3, 43],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 3, -43],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -4, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 4, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -4, 44],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 4, -44],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -5, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 5, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, -5, 45],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-321, 5, -45],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([322, 323, 324]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-322, -323),
#   (-322, -324),
#   (-323, -324),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -6, 1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 6, -1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -6, 1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 6, -1],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -6, -1],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -6, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 6, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -6, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -6, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 6, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -6, 46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -6, 46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 6, -46],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -7, 2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 7, -2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -7, 2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 7, -2],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -7, -2],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -7, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 7, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -7, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -7, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 7, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -7, 47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -7, 47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 7, -47],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -8, 3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 8, -3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -8, 3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 8, -3],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -8, -3],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -8, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 8, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -8, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -8, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 8, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -8, 48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -8, 48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 8, -48],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -9, 4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 9, -4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -9, 4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 9, -4],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -9, -4],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -9, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 9, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -9, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -9, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 9, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -9, 49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -9, 49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 9, -49],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -10, 5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 10, -5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -10, 5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 10, -5],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-324, -10, -5],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, -10, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-322, 10, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-323, -10, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -10, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 10, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-322, -10, -50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, -10, 50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-323, 10, -50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, -10, 50],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-324, 10, -50],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([325, 326, 327]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-325, -326),
#   (-325, -327),
#   (-326, -327),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -11, 6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 11, -6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -11, 6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 11, -6],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -11, -6],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -11, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 11, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -11, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -11, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 11, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -11, 51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -11, 51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 11, -51],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -12, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 12, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -12, 7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 12, -7],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -12, -7],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -12, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 12, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -12, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -12, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 12, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -12, 52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -12, 52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 12, -52],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -13, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 13, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -13, 8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 13, -8],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -13, -8],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -13, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 13, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -13, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -13, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 13, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -13, 53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -13, 53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 13, -53],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -14, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 14, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -14, 9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 14, -9],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -14, -9],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -14, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 14, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -14, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -14, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 14, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -14, 54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -14, 54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 14, -54],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -15, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 15, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -15, 10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 15, -10],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-327, -15, -10],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, -15, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-325, 15, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-326, -15, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -15, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 15, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-325, -15, -55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, -15, 55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-326, 15, -55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, -15, 55],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-327, 15, -55],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([328, 329, 330]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-328, -329),
#   (-328, -330),
#   (-329, -330),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -16, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 16, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -16, 11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 16, -11],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -16, -11],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -16, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 16, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -16, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -16, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 16, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -16, 56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -16, 56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 16, -56],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -17, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 17, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -17, 12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 17, -12],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -17, -12],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -17, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 17, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -17, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -17, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 17, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -17, 57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -17, 57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 17, -57],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -18, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 18, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -18, 13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 18, -13],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -18, -13],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -18, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 18, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -18, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -18, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 18, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -18, 58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -18, 58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 18, -58],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -19, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 19, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -19, 14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 19, -14],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -19, -14],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -19, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 19, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -19, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -19, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 19, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -19, 59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -19, 59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 19, -59],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -20, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 20, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -20, 15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 20, -15],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-330, -20, -15],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, -20, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-328, 20, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-329, -20, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -20, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 20, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-328, -20, -60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, -20, 60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-329, 20, -60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, -20, 60],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-330, 20, -60],
#   ('time_direction: ', 1589834045.6374643),
#   dict_values([331, 332, 333]),
#   ('time_direction_no_two: ', 1589834045.6374643),
#   (-331, -332),
#   (-331, -333),
#   (-332, -333),
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -21, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 21, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -21, 16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 21, -16],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-333, -21, -16],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -21, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 21, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-332, -21, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -21, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 21, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-331, -21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -21, 61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -21, 61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 21, -61],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -22, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 22, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, -22, 17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-332, 22, -17],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-333, -22, -17],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, -22, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-331, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6374643),
#   [-332, -22, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, -22, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6374643),
#   [-333, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384628),
#   [-331, -22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-331, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -23, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -24, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -25, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -65],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([334, 335, 336]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-334, -335),
#   (-334, -336),
#   (-335, -336),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -26, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -27, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -28, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 28, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -28, 23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 28, -23],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -28, -23],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -28, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 28, -33],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -28, -33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -28, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 28, -33],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -28, 68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -28, 68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 28, -68],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -29, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 29, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -29, 24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 29, -24],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -29, -24],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -29, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 29, -34],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -29, -34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -29, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 29, -34],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -29, 69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -29, 69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 29, -69],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -30, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 30, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -30, 25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 30, -25],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -30, -25],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -30, 35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 30, -35],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -30, -35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -30, 35],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 30, -35],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -30, -70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -30, 70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 30, -70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -30, 70],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 30, -70],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([337, 338, 339]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-337, -338),
#   (-337, -339),
#   (-338, -339),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -31, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 31, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -31, 26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 31, -26],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -31, -26],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -31, 36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 31, -36],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -31, -36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -31, 36],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 31, -36],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -31, 71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -31, 71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 31, -71],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -32, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 32, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -32, 27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 32, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -32, -27],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -32, 37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 32, -37],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -32, -37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -32, 37],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 32, -37],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -32, 72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -32, 72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 32, -72],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -33, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 33, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -33, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 33, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -33, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -33, 38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 33, -38],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -33, -38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -33, 38],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 33, -38],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -33, 73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -33, 73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 33, -73],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -34, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 34, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -34, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 34, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -34, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -34, 39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 34, -39],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -34, -39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -34, 39],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 34, -39],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -34, 74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -34, 74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 34, -74],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -35, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 35, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -35, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 35, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-339, -35, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, -35, 40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-337, 35, -40],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-338, -35, -40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -35, 40],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 35, -40],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-337, -35, -75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, -35, 75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-338, 35, -75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, -35, 75],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-339, 35, -75],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([340]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -36, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 36, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -36, 76],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 36, -76],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -37, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 37, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -37, 77],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 37, -77],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -38, 33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 38, -33],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -38, 78],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 38, -78],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, -39, 34],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-340, 39, -34],
#   ...],
#  [[-333, 22, -27],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384628),
#   [-331, -22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-332, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, -22, 62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-333, 22, -62],
#   ('time_direction_direction_imply_color: ', 1589834045.6384628),
#   [-331, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -18],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -23, -18],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -23, -28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 28],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -28],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -23, 63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 23, -63],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -19],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -24, -19],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -24, -29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 29],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -29],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -24, 64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 24, -64],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -20],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-333, -25, -20],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-331, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-332, -25, -30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 30],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -30],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-331, -25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-332, 25, -65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, -25, 65],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-333, 25, -65],
#   ('time_direction: ', 1589834045.6384883),
#   dict_values([334, 335, 336]),
#   ('time_direction_no_two: ', 1589834045.6384883),
#   (-334, -335),
#   (-334, -336),
#   (-335, -336),
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -21],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -26, -21],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -26, -31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 31],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -31],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -26, 66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 26, -66],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, 27, -22],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-336, -27, -22],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-334, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-335, -27, -32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, -27, 32],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-336, 27, -32],
#   ('time_direction_reduce_neigbor: ', 1589834045.6384883),
#   [-334, -27, -67],
#   ('time_direction_direction_imply_color: ', 1589834045.6384883),
#   [-335, -27, 67],
# ...
#   [-550, 271, -266],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -271, -266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -271, 266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 271, -266],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -271, -266],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -271, -276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -271, -276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -271, 276],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 271, -276],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 271, -231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -271, 231],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -271, -231],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 271, -311],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -271, -311],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -271, 311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 271, -311],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -272, 267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 272, -267],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -272, -267],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -272, -277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -272, -277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -272, 277],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 272, -277],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 272, -232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -272, 232],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -272, -232],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 272, -312],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -272, -312],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -272, 312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 272, -312],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -273, 268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 273, -268],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -273, -268],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -273, -278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -273, -278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -273, 278],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 273, -278],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 273, -233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -273, 233],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -273, -233],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 273, -313],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -273, -313],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -273, 313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 273, -313],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -274, 269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 274, -269],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -274, -269],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -274, -279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -274, -279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -274, 279],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 274, -279],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 274, -234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -274, 234],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -274, -234],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 274, -314],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -274, -314],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -274, 314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 274, -314],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -275, 270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 275, -270],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -275, -270],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-548, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-549, -275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -275, -280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -275, -280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -275, 280],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 275, -280],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-550, 275, -235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, -275, 235],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-551, 275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-552, -275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-553, -275, -235],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-548, -275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-549, 275, -315],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-550, -275, -315],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-551, -275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-552, 275, -315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, -275, 315],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-553, 275, -315],
#   ('time_direction: ', 1589834045.6609497),
#   dict_values([554, 555, 556]),
#   ('time_direction_no_two: ', 1589834045.6609497),
#   (-554, -555),
#   (-554, -556),
#   (-555, -556),
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, -286, 281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, 286, -281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-555, -286, 281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-555, 286, -281],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-556, -286, -281],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, -286, 291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-554, 286, -291],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   [-555, -286, -291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-556, -286, 291],
#   ('time_direction_direction_imply_color: ', 1589834045.6609497),
#   [-556, 286, -291],
#   ('time_direction_reduce_neigbor: ', 1589834045.6609497),
#   ...],
#  []]
