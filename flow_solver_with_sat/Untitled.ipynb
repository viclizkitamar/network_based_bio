30), (-29, -31), (-30, -31), [-29, -11, -9], [-30, -11, 9], [-30, 11, -9], [-31, -11, 9], [-31, 11, -9], [-29, -11, 5], [-29, 11, -5], [-30, -11, 5], [-30, 11, -5], [-31, -11, -5], [-29, -11, 17], [-29, 11, -17], [-30, -11, -17], [-31, -11, 17], [-31, 11, -17], [-29, -12, -10], [-30, -12, 10], [-30, 12, -10], [-31, -12, 10], [-31, 12, -10], [-29, -12, 6], [-29, 12, -6], [-30, -12, 6], [-30, 12, -6], [-31, -12, -6], [-29, -12, 18], [-29, 12, -18], [-30, -12, -18], [-31, -12, 18], [-31, 12, -18], dict_values([32, 33, 34]), (-32, -33), (-32, -34), (-33, -34), [-32, -15, 13], [-32, 15, -13], [-33, -15, 13], [-33, 15, -13], [-34, -15, -13], [-32, -15, 17], [-32, 15, -17], [-33, -15, -17], [-34, -15, 17], [-34, 15, -17], [-32, -15, -9], [-33, -15, 9], [-33, 15, -9], [-34, -15, 9], [-34, 15, -9], [-32, -16, 14], [-32, 16, -14], [-33, -16, 14], [-33, 16, -14], [-34, -16, -14], [-32, -16, 18], [-32, 16, -18], [-33, -16, -18], [-34, -16, 18], [-34, 16, -18], [-32, -16, -10], [-33, -16, 10], [-33, 16, -10], [-34, -16, 10], [-34, 16, -10]]"

# %%
t=t.replace('[','')
t=t.replace(']','')
t=t.replace('(','')
t=t.replace(')','')
t=t.replace('dict_values','')

# %%
t
# Out:
# '1, -2, 3, 7, -3, -7, 4, -3, 2, 6, 10, -2, -6, -2, -10, -6, -10, 5, 6, -5, -6, 7, 8, -7, -8, 9, 10, -9, -10, 11, 12, -11, -12, 13, -14, 15, 7, -15, -7, 15, 16, -15, -16, 18, -17, 16, 12, -16, -12, 19, -19, -5, 3, -19, 5, -3, -19, -5, 11, -19, 5, -11, -19, -6, 4, -19, 6, -4, -19, -6, 12, -19, 6, -12, 20, 21, 22, -20, -21, -20, -22, -21, -22, -20, -7, -9, -21, -7, 9, -21, 7, -9, -22, -7, 9, -22, 7, -9, -20, -7, 1, -20, 7, -1, -21, -7, 1, -21, 7, -1, -22, -7, -1, -20, -7, 13, -20, 7, -13, -21, -7, -13, -22, -7, 13, -22, 7, -13, -20, -8, -10, -21, -8, 10, -21, 8, -10, -22, -8, 10, -22, 8, -10, -20, -8, 2, -20, 8, -2, -21, -8, 2, -21, 8, -2, -22, -8, -2, -20, -8, 14, -20, 8, -14, -21, -8, -14, -22, -8, 14, -22, 8, -14, 23, 24, 25, 26, 27, 28, -23, -24, -23, -25, -23, -26, -23, -27, -23, -28, -24, -25, -24, -26, -24, -27, -24, -28, -25, -26, -25, -27, -25, -28, -26, -27, -26, -28, -27, -28, -23, -9, 7, -23, 9, -7, -24, -9, -7, -25, -9, 7, -25, 9, -7, -26, -9, -7, -27, -9, 7, -27, 9, -7, -2
# ...

# %%
with open("clauses3X3_1.txt", "w") as text_file:
    text_file.write(t)

# %%
t=t.split(",")

# %%
with open(r"C:\Users\vicli\Desktop\תמר לימודים\תואר שני\thesis\documation\sudoku\sudoku-sat-solver\flow game using sat\flow_solver_with_sat\clauses3X3_1_linebyline.txt", 'r') as istr:
    with open(r"C:\Users\vicli\Desktop\תמר לימודים\תואר שני\thesis\documation\sudoku\sudoku-sat-solver\flow game using sat\flow_solver_with_sat\clauses3X3_1_linebyline - Copy.txt", 'w') as ostr:
        for line in istr:
            line = line.rstrip('\n') + '0'
            print(line, file=ostr)

# %%
#with open ("clauses3X3_1.txt", 'r') as istr:
with open("clauses3X3_1.txt", "w") as text_file:
    for i, line in enumerate(text_file):
            # Get rid of the trailing newline (if any).
            line = line.rstrip('\n')
            line += '0'
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-8-89a601187d44> in <module>
#       1 #with open ("clauses3X3_1.txt", 'r') as istr:
#       2 with open("clauses3X3_1.txt", "w") as text_file:
# ----> 3     for i, line in enumerate(text_file):
#       4             # Get rid of the trailing newline (if any).
#       5             line = line.rstrip('\n')
#
# UnsupportedOperation: not readable

# %%
t
# Out:
# ['1',
#  ' -2',
#  ' 3',
#  ' 7',
#  ' -3',
#  ' -7',
#  ' 4',
#  ' -3',
#  ' 2',
#  ' 6',
#  ' 10',
#  ' -2',
#  ' -6',
#  ' -2',
#  ' -10',
#  ' -6',
#  ' -10',
#  ' 5',
#  ' 6',
#  ' -5',
#  ' -6',
#  ' 7',
#  ' 8',
#  ' -7',
#  ' -8',
#  ' 9',
#  ' 10',
#  ' -9',
#  ' -10',
#  ' 11',
#  ' 12',
#  ' -11',
#  ' -12',
#  ' 13',
#  ' -14',
#  ' 15',
#  ' 7',
#  ' -15',
#  ' -7',
#  ' 15',
#  ' 16',
#  ' -15',
#  ' -16',
#  ' 18',
#  ' -17',
#  ' 16',
#  ' 12',
#  ' -16',
#  ' -12',
#  ' 19',
#  ' -19',
#  ' -5',
#  ' 3',
#  ' -19',
#  ' 5',
#  ' -3',
#  ' -19',
#  ' -5',
#  ' 11',
#  ' -19',
#  ' 5',
#  ' -11',
#  ' -19',
#  ' -6',
#  ' 4',
#  ' -19',
#  ' 6',
#  ' -4',
#  ' -19',
#  ' -6',
#  ' 12',
#  ' -19',
#  ' 6',
#  ' -12',
#  ' 20',
#  ' 21',
#  ' 22',
#  ' -20',
#  ' -21',
#  ' -20',
#  ' -22',
#  ' -21',
#  ' -22',
#  ' -20',
#  ' -7',
#  ' -9',
#  ' -21',
#  ' -7',
#  ' 9',
#  ' -21',
#  ' 7',
#  ' -9',
#  ' -22',
#  ' -7',
#  ' 9',
#  ' -22',
#  ' 7',
#  ' -9',
# ...

# %%
for j in range(0,len(t),3):
 #   print(j)
    print(t[j],t[j+1],t[j+2])
 
    print("\n")
# Out:
# 1  -2  3
#
#
#  7  -3  -7
#
#
#  4  -3  2
#
#
#  6  10  -2
#
#
#  -6  -2  -10
#
#
#  -6  -10  5
#
#
#  6  -5  -6
#
#
#  7  8  -7
#
#
#  -8  9  10
#
#
#  -9  -10  11
#
#
#  12  -11  -12
#
#
#  13  -14  15
#
#
#  7  -15  -7
#
#
#  15  16  -15
#
#
#  -16  18  -17
#
#
#  16  12  -16
#
#
#  -12  19  -19
#
#
#  -5  3  -19
#
#
#  5  -3  -19
#
#
#  -5  11  -19
#
#
#  5  -11  -19
#
#
#  -6  4  -19
#
#
#  6  -4  -19
#
#
#  -6  12  -19
#
#
#  6  -12  20
#
#
#  21  22  -20
#
#
#  -21  -20  -22
#
#
#  -21  -22  -20
#
#
#  -7  -9  -21
#
#
#  -7  9  -21
#
#
#  7  -9  -22
#
#
#  -7  9  -22
#
#
#  7  -9  -20
#
#
#  -7  1  -20
#
#
#  7  -1  -21
#
#
#  -7  1  -21
#
#
#  7  -1  -22
#
#
#  -7  -1  -20
#
#
#  -7  13  -20
#
#
#  7  -13  -21
#
#
#  -7  -13  -22
#
#
#  -7  13  -22
#
#
#  7  -13  -20
#
#
#  -8  -10  -21
#
#
#  -8  10  -21
#
#
#  8  -10  -22
#
#
#  -8  10  -22
#
#
#  8  -10  -20
#
#
#  -8  2  -20
#
#
#  8  -2  -21
#
#
#  -8  2  -21
#
#
#  8  -2  -22
#
#
#  -8  -2  -20
#
#
#  -8  14  -20
#
#
# ...

# %%
        sol = pycosat.solve(clauses) # pylint: disable=E1101
        print("sol from solve_sat")
        if not isinstance(sol, list):
            decoded = None
            all_decoded.append(decoded)
            break

# %%
        for sol2 in list(itertools.islice(pycosat.itersolve(clauses))):
            sol=sol2
            if str(sol) == 'UNSAT' != 'UNSAT':
                continue
            print("sol from solve_sat",sol)
            sol=sol2
           if str(sol2) == 'UNSAT':
                 print('UNSAT')

# %%
clauses=[]

# %%
f = open(r"C:\Users\vicli\Desktop\תמר לימודים\תואר שני\thesis\documation\sudoku\sudoku-sat-solver\flow game using sat\flow_solver_with_sat\clauses3X3_1_for_sol.txt", "r")
#f = f.strip()
for x in f:
    x=x.rstrip()
    list_x=x.split(',')
    clauses.append(int(list_x[0]))
    clauses.append(int(list_x[1]))
    clauses.append(int(list_x[2]))

# %%
clauses
# Out:
# [1,
#  -2,
#  3,
#  7,
#  -3,
#  -7,
#  4,
#  -3,
#  2,
#  6,
#  10,
#  -2,
#  -6,
#  -2,
#  -10,
#  -6,
#  -10,
#  5,
#  6,
#  -5,
#  -6,
#  7,
#  8,
#  -7,
#  12,
#  -11,
#  -12,
#  -8,
#  9,
#  10,
#  -9,
#  -10,
#  11,
#  13,
#  -14,
#  15,
#  7,
#  -15,
#  -7,
#  15,
#  16,
#  -15,
#  -16,
#  18,
#  -17,
#  16,
#  12,
#  -16,
#  -12,
#  19,
#  -19,
#  -5,
#  3,
#  -19,
#  5,
#  -3,
#  -19,
#  -5,
#  11,
#  -19,
#  5,
#  -11,
#  -19,
#  -6,
#  4,
#  -19,
#  6,
#  -4,
#  -19,
#  -6,
#  12,
#  -19,
#  6,
#  -12,
#  20,
#  21,
#  22,
#  -20,
#  -21,
#  -20,
#  -22,
#  -21,
#  -22,
#  -20,
#  -7,
#  -9,
#  -21,
#  -7,
#  9,
#  -21,
#  7,
#  -9,
#  -22,
#  -7,
#  9,
#  -22,
#  7,
#  -9,
#  -20,
#  -7,
#  1,
#  -20,
#  7,
#  -1,
#  -21,
#  -7,
#  1,
#  -21,
#  7,
#  -1,
#  -22,
#  -7,
#  -1,
#  -20,
#  -7,
#  13,
#  -20,
#  7,
#  -13,
#  -21,
#  -7,
#  -13,
#  -22,
#  -7,
#  13,
#  -22,
#  7,
#  -13,
#  -20,
#  -8,
#  -10,
#  -21,
#  -8,
#  10,
#  -21,
#  8,
#  -10,
#  -22,
#  -8,
# ...

# %%
ANSI_LOOKUP = dict(R=101, B=104, Y=103, G=42,
                   O=43, C=106, M=105, m=41,
                   P=45, A=100, W=107, g=102,
                   T=47, b=44, c=46, p=35)

# %%
DELTAS = [(LEFT, 0, -1),
          (RIGHT, 0, 1),
          (TOP, -1, 0),
          (BOTTOM, 1, 0)]

# %%
sol_3X3=[1,  -2,  3,  7,  -3,  -7,  4,  -3,  2,  6,  10,  -2,  -6,  -2,  -10,  -6,  -10,  5,  6,  -5,  -6,  7,  8,  -7,  12,  -11,  -12,  -8,  9,  10,  -9,  -10,  11,  13,  -14,  15,  7,  -15,  -7,  15,  16,  -15,  -16,  18,  -17,  16,  12,  -16,  -12,  19,  -19,  -5,  3,  -19,  5,  -3,  -19,  -5,  11,  -19,  5,  -11,  -19,  -6,  4,  -19,  6,  -4,  -19,  -6,  12,  -19,  6,  -12,  20,  21,  22,  -20,  -21,  -20,  -22,  -21,  -22,  -20,  -7,  -9,  -21,  -7,  9,  -21,  7,  -9,  -22,  -7,  9,  -22,  7,  -9,  -20,  -7,  1,  -20,  7,  -1,  -21,  -7,  1,  -21,  7,  -1,  -22,  -7,  -1,  -20,  -7,  13,  -20,  7,  -13,  -21,  -7,  -13,  -22,  -7,  13,  -22,  7,  -13,  -20,  -8,  -10,  -21,  -8,  10,  -21,  8,  -10,  -22,  -8,  10,  -22,  8,  -10,  -20,  -8,  2,  -20,  8,  -2,  -21,  -8,  2,  -21,  8,  -2,  -22,  -8,  -2,  -20,  -8,  14,  -20,  8,  -14,  -21,  -8,  -14,  -22,  -8,  14,  -22,  8,  -14,  23,  24,  25,  26,  27,  28,  -23,  -24,  -23,  -25,  -23,  -26,  -23,  -27,  -23,  -28,  -24,  -25,  -24,  -26,  -24,  -27,  -24,  -28,  -25,  -26,  -25,  -27,  -25,  -28,  -26,  -27,  -26,  -28,  -27,  -28,  -23,  -9,  7,  -23,  9,  -7,  -24,  -9,  -7,  -25,  -9,  7,  -25,  9,  -7,  -26,  -9,  -7,  -27,  -9,  7,  -27,  9,  -7,  -28,  -9,  -7,  -23,  -9,  11,  -23,  9,  -11,  -24,  -9,  -11,  -25,  -9,  -11,  -26,  -9,  11,  -26,  9,  -11,  -27,  -9,  -11,  -28,  -9,  11,  -28,  9,  -11,  -23,  -9,  -3,  -24,  -9,  3,  -24,  9,  -3,  -25,  -9,  3,  -25,  9,  -3,  -26,  -9,  3,  -26,  9,  -3,  -27,  -9,  -3,  -28,  -9,  -3,  -23,  -9,  -15,  -24,  -9,  15,  -24,  9,  -15,  -25,  -9,  -15,  -26,  -9,  -15,  -27,  -9,  15,  -27,  9,  -15,  -28,  -9,  15,  -28,  9,  -15,  -23,  -10,  8,  -23,  10,  -8,  -24,  -10,  -8,  -25,  -10,  8,  -25,  10,  -8,  -26,  -10,  -8,  -27,  -10,  8,  -27,  10,  -8,  -28,  -10,  -8,  -23,  -10,  12,  -23,  10,  -12,  -24,  -10,  -12,  -25,  -10,  -12,  -26,  -10,  12,  -26,  10,  -12,  -27,  -10,  -12,  -28,  -10,  12,  -28,  10,  -12,  -23,  -10,  -4,  -24,  -10,  4,  -24,  10,  -4,  -25,  -10,  4,  -25,  10,  -4,  -26,  -10,  4,  -26,  10,  -4,  -27,  -10,
# %%
for item in sol_8X8:
    if '42' in str(item):
        print(item)
# Out:
# -42
# -142
# -242
# -342
# -420
# -421
# -422
# 423
# -424
# -425
# -426
# -427
# -428
# -429
# -442
# -542

# %%
    while True:

        sol = pycosat.solve(clauses) # pylint: disable=E1101

        if not isinstance(sol, list):
            decoded = None
            all_decoded.append(decoded)
            break

        decoded = decode_solution(puzzle, colors, color_var, dir_vars, sol)
        all_decoded.append(decoded)

        extra_clauses = detect_cycles(decoded, dir_vars)
        print(extra_clauses)

        if not extra_clauses:
            break

        clauses += extra_clauses
        repairs += 1

    solve_time = (datetime.now() - start).total_seconds()

    if not options.quiet:
        if options.display_cycles:
            for cycle_decoded in all_decoded[:-1]:
                print('intermediate solution with cycles:')
                show_solution(options, colors, cycle_decoded)


        if decoded is None:
            print('solver returned {} after {:,} cycle '\
                    'repairs and {:.3f} seconds'.format(str(sol), repairs, solve_time))
        else:
            print('obtained solution after {:,} cycle repairs '\
                    'and {:.3f} seconds:'.format(repairs, solve_time))
            show_solution(options, colors, decoded)

    return sol, decoded, repairs, solve_time

# %%
clauses=[]
with open(r"C:\Users\vicli\Desktop\תמר לימודים\תואר שני\thesis\documation\sudoku\sudoku-sat-solver\flow game using sat\flow_solver_with_sat\clauses3X3_1_linebyline.txt", 'r') as f:
    for line in f.readlines():
        clauses.append(line.rstrip('\n'))

# %%
clauses
# Out:
# ['1 -2 3 ',
#  '7 -3 -7 ',
#  '4 -3 2 ',
#  '6 10 -2 ',
#  '-6 -2 -10 ',
#  '-6 -10 5 ',
#  '6 -5 -6 ',
#  '7 8 -7 ',
#  '12 -11 -12 ',
#  '-8 9 10 ',
#  '-9 -10 11 ',
#  '13 -14 15 ',
#  '7 -15 -7 ',
#  '15 16 -15 ',
#  '-16 18 -17 ',
#  '16 12 -16 ',
#  '-12 19 -19 ',
#  '-5 3 -19 ',
#  '5 -3 -19 ',
#  '-5 11 -19 ',
#  '5 -11 -19 ',
#  '-6 4 -19 ',
#  '6 -4 -19 ',
#  '-6 12 -19 ',
#  '6 -12 20 ',
#  '21 22 -20 ',
#  '-21 -20 -22 ',
#  '-21 -22 -20 ',
#  '-7 -9 -21 ',
#  '-7 9 -21 ',
#  '7 -9 -22 ',
#  '-7 9 -22 ',
#  '7 -9 -20 ',
#  '-7 1 -20 ',
#  '7 -1 -21 ',
#  '-7 1 -21 ',
#  '7 -1 -22 ',
#  '-7 -1 -20 ',
#  '-7 13 -20 ',
#  '7 -13 -21 ',
#  '-7 -13 -22 ',
#  '-7 13 -22 ',
#  '7 -13 -20 ',
#  '-8 -10 -21 ',
#  '-8 10 -21 ',
#  '8 -10 -22 ',
#  '-8 10 -22 ',
#  '8 -10 -20 ',
#  '-8 2 -20 ',
#  '8 -2 -21 ',
#  '-8 2 -21 ',
#  '8 -2 -22 ',
#  '-8 -2 -20 ',
#  '-8 14 -20 ',
#  '8 -14 -21 ',
#  '-8 -14 -22 ',
#  '-8 14 -22 ',
#  '8 -14 23 ',
#  '24 25 26 ',
#  '27 28 -23 ',
# ...
